# %%
import pandas as pd

# %%
df = pd.read_excel(
    'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Canada.xlsx' ,skiprows=range(21),skipfooter=2)

# %%
df.head()
# Out:
#    Immigrants    Citizens Northern America Northern America.1    ..  ...1  \
# 0  Immigrants  Foreigners           Africa     Eastern Africa  1471  1641
# 1  Immigrants  Foreigners           Africa      Middle Africa    33    27
# 2  Immigrants  Foreigners           Africa    Northern Africa  1100  1268
# 3  Immigrants  Foreigners           Africa    Southern Africa  1041  1126
# 4  Immigrants  Foreigners           Africa     Western Africa   306   301
#
#    ...2  ...3  ...4  ...5  ...  ...18  ...19  ...20  ...21  ...22  ...23  \
# 0  1426  1094  1187  1134  ...   7083   6750   6669   6705   6922   8591
# 1    44    32    42    30  ...   2802   2834   2951   3034   3255   3369
# 2  1348   936   842   840  ...  11323  12705  11750  13456  16320  19271
# 3   791   387   297   327  ...   1012   1148   1230   1184   1235   1306
# 4   210   222   271   319  ...   5303   5751   5684   5511   6802   8355
#
#      1.3    1.4 Unnamed: 37  Unnamed: 38
# ...

# %%
df.drop(['Unnamed: 37','Unnamed: 38'], axis=1, inplace = True)

# %%
df.head()
# Out:
#    Immigrants    Citizens Northern America Northern America.1    ..  ...1  \
# 0  Immigrants  Foreigners           Africa     Eastern Africa  1471  1641
# 1  Immigrants  Foreigners           Africa      Middle Africa    33    27
# 2  Immigrants  Foreigners           Africa    Northern Africa  1100  1268
# 3  Immigrants  Foreigners           Africa    Southern Africa  1041  1126
# 4  Immigrants  Foreigners           Africa     Western Africa   306   301
#
#    ...2  ...3  ...4  ...5  ...  ...16  ...17  ...18  ...19  ...20  ...21  \
# 0  1426  1094  1187  1134  ...   5808   7726   7083   6750   6669   6705
# 1    44    32    42    30  ...   1929   2452   2802   2834   2951   3034
# 2  1348   936   842   840  ...  11355  12478  11323  12705  11750  13456
# 3   791   387   297   327  ...   1258   1203   1012   1148   1230   1184
# 4   210   222   271   319  ...   3016   4333   5303   5751   5684   5511
#
#    ...22  ...23    1.3    1.4
# 0   6922   8591   8956   8846
# ...

# %%
df.drop(['Northern America.1','Immigrants','Citizens'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Northern America    ..  ...1  ...2  ...3  ...4  ...5  ...6  ...7  ...8  ...  \
# 0           Africa  1471  1641  1426  1094  1187  1134  1454  2734  3237  ...
# 1           Africa    33    27    44    32    42    30    61   100    91  ...
# 2           Africa  1100  1268  1348   936   842   840  1115  1864  2239  ...
# 3           Africa  1041  1126   791   387   297   327   725  1480  1329  ...
# 4           Africa   306   301   210   222   271   319   427  1316   656  ...
#
#    ...16  ...17  ...18  ...19  ...20  ...21  ...22  ...23    1.3    1.4
# 0   5808   7726   7083   6750   6669   6705   6922   8591   8956   8846
# 1   1929   2452   2802   2834   2951   3034   3255   3369   3146   4602
# 2  11355  12478  11323  12705  11750  13456  16320  19271  15712  15453
# 3   1258   1203   1012   1148   1230   1184   1235   1306   1049   1348
# 4   3016   4333   5303   5751   5684   5511   6802   8355   6578   7834
#
# [5 rows x 34 columns]

# %%
df['Total']=df.sum(axis=0)

# %%
df.head()
# Out:
#   Northern America    ..  ...1  ...2  ...3  ...4  ...5  ...6  ...7  ...8  ...  \
# 0           Africa  1471  1641  1426  1094  1187  1134  1454  2734  3237  ...
# 1           Africa    33    27    44    32    42    30    61   100    91  ...
# 2           Africa  1100  1268  1348   936   842   840  1115  1864  2239  ...
# 3           Africa  1041  1126   791   387   297   327   725  1480  1329  ...
# 4           Africa   306   301   210   222   271   319   427  1316   656  ...
#
#    ...17  ...18  ...19  ...20  ...21  ...22  ...23    1.3    1.4  Total
# 0   7726   7083   6750   6669   6705   6922   8591   8956   8846    NaN
# 1   2452   2802   2834   2951   3034   3255   3369   3146   4602    NaN
# 2  12478  11323  12705  11750  13456  16320  19271  15712  15453    NaN
# 3   1203   1012   1148   1230   1184   1235   1306   1049   1348    NaN
# 4   4333   5303   5751   5684   5511   6802   8355   6578   7834    NaN
#
# [5 rows x 35 columns]

# %%
## Yaha sum me NaN isliye aa rha h kyuki row m Africa bhi add ho rha h... str + numerical = impossible.

# %%
df.set_index('Northern America',inplace=True)

# %%
df.columns=['Immigrants','Citizens','Northern America','Northern America.1',1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-ab14ff7b5d2e> in <module>
# ----> 1 df.columns=['Immigrants','Citizens','Northern America','Northern America.1',1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5476         try:
#    5477             object.__getattribute__(self, name)
# -> 5478             return object.__setattr__(self, name, value)
#    5479         except AttributeError:
#    5480             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
# ...

# %%
df.head()

# %%
df.drop([2013,2014],axis=1,inplace=True)

# %%
df.head()

# %%
df

# %%
df.drop(['Immigrants','Citizens','Northern America.1'],axis=1,inplace=True)

# %%
df.dropna()

# %%
df.set_index('Northern America',inplace=True)

# %%
df.head()

# %%
df['Total']=df.sum(axis=0)

# %%
df.groupby(df.columns, axis=1).sum()

# %%
# let's examine the types of the column labels
all(isinstance(column, str) for column in df.columns)
